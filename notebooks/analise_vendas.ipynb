# %%
import pandas as pd

df = pd.read_csv('../data/vendas.csv')
df.head()
# Out:
#    data_venda   produto    categoria  quantidade  preco_unitario    regiao  \
# 0  2024-01-05  Notebook  Eletrônicos           2            3500   Sudeste
# 1  2024-01-10     Mouse  Eletrônicos           5              80   Sudeste
# 2  2024-02-02   Teclado  Eletrônicos           3             150       Sul
# 3  2024-02-15   Monitor  Eletrônicos           1            1200   Sudeste
# 4  2024-03-01   Cadeira   Escritório           2             900  Nordeste
#
#   vendedor
# 0      Ana
# 1   Carlos
# 2   Marcos
# 3      Ana
# 4    Paula
